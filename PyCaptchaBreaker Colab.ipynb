# %% [markdown]
# <a href="https://colab.research.google.com/github/NagarajuGunda/PyCaptchaBreaker/blob/master/PyCaptchaBreaker%20Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
# !apt-get install -qq protobuf-compiler python-tk

# %%
os.chdir('/content')

# %%
# !git clone --quiet https://github.com/tensorflow/models.git

# %%
# !pip install -q Cython contextlib2 pillow lxml matplotlib PyDrive

# %%
# !pip install -q pycocotools

# %%
# %cd /content/models/research
# Out:
# /content/models/research

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
import os
os.environ['PYTHONPATH'] += ':/content/models/research/:/content/models/research/slim/'

# %%
# !python object_detection/builders/model_builder_test.py
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# ............s...
# ----------------------------------------------------------------------
# Ran 16 tests in 0.076s
#
# OK (skipped=1)

# %%
# %cd /content/
# !git clone https://github.com/NagarajuGunda/PyCaptchaBreaker.git PyCaptchaBreaker
# %cd PyCaptchaBreaker
# Out:
# /content
# Cloning into 'PyCaptchaBreaker'...
# remote: Enumerating objects: 234, done.
# remote: Total 234 (delta 0), reused 0 (delta 0), pack-reused 234
# Receiving objects: 100% (234/234), 97.30 MiB | 40.21 MiB/s, done.
# Resolving deltas: 100% (102/102), done.
# Checking out files: 100% (222/222), done.
# /content/PyCaptchaBreaker

# %%
# !ls
# Out:
# CAPTCHA_images				  generate_tfrecord.bat  train.py
# CAPTCHA_training			  generate_tfrecord.py	 xml_to_csv.bat
# faster_rcnn_inception_v2_coco_2018_01_28  training.bat		 xml_to_csv.py

# %%
# !python train.py --logtostderr --train_dir=CAPTCHA_training_dir/ --pipeline_config_path=CAPTCHA_training/faster_rcnn_inception_v2_coco.config &> /content/PyCaptchaBreaker/tb.log &

# %%
from IPython.display import clear_output

while True:
    clear_output()
    # !tail -n 5 /content/PyCaptchaBreaker/tb.log && sleep 5

# %%
# !ls -lrt CAPTCHA_training_dir
# Out:
# total 614904
# -rw-r--r-- 1 root root      3672 Mar  9 11:40 pipeline.config
# -rw-r--r-- 1 root root  10335943 Mar  9 11:41 graph.pbtxt
# -rw-r--r-- 1 root root 104444376 Mar  9 14:51 model.ckpt-41975.data-00000-of-00001
# -rw-r--r-- 1 root root     25571 Mar  9 14:51 model.ckpt-41975.index
# -rw-r--r-- 1 root root   5371527 Mar  9 14:51 model.ckpt-41975.meta
# -rw-r--r-- 1 root root 104444376 Mar  9 15:01 model.ckpt-44181.data-00000-of-00001
# -rw-r--r-- 1 root root     25571 Mar  9 15:01 model.ckpt-44181.index
# -rw-r--r-- 1 root root   5371527 Mar  9 15:01 model.ckpt-44181.meta
# -rw-r--r-- 1 root root 104444376 Mar  9 15:11 model.ckpt-46384.data-00000-of-00001
# -rw-r--r-- 1 root root     25571 Mar  9 15:11 model.ckpt-46384.index
# -rw-r--r-- 1 root root   5371527 Mar  9 15:11 model.ckpt-46384.meta
# -rw-r--r-- 1 root root 104444376 Mar  9 15:21 model.ckpt-48592.data-00000-of-00001
# -rw-r--r-- 1 root root     25571 Mar  9 15:21 model.ckpt-48592.index
# ...

# %%
import tensorflow as tf
import re
for event in tf.train.summary_iterator('CAPTCHA_training_dir/events.out.tfevents.1552117495.7216cb78b690'):
    for value in event.summary.value:
        if value.tag == 'Losses/Loss/RPNLoss/objectness_loss':
            if value.HasField('simple_value'):
                print(value.simple_value)

# %%
# !rm -r exported_graphs; rm -f exported_graphs.zip; mkdir exported_graphs

# !export CHECKPOINT_NUMBER=50796; python /content/models/research/object_detection/export_inference_graph.py \
--input_type image_tensor \
--pipeline_config_path CAPTCHA_training/faster_rcnn_inception_v2_coco.config \
--trained_checkpoint_prefix CAPTCHA_training_dir/model.ckpt-${CHECKPOINT_NUMBER} \
--output_directory exported_graphs
# Out:
# WARNING:tensorflow:From /content/models/research/object_detection/exporter.py:309: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/tensor_array_ops.py:162: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/image_ops_impl.py:1055: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# ...
